# %% [markdown]
# # Kuiper Asteroid Families

# %%
import csv
import numpy as np
from google.colab import drive
drive.mount('/content/gdrive')
data = np.genfromtxt(r"/content/gdrive/My Drive/tno.txt", delimiter = ",",names=True,dtype=None)
tdv_Values = []
print(data)
print(len(data))

def clac(a1, a2, a3, a4, e1, e2, e3, e4, i1, i2, i3, i4):
  aValues = [a1, a2, a3, a4]
  eValues = [e1, e2, e3, e4]
  iValues = [i1, i2, i3, i4]
  
  tdv = 2.5*(max(aValues)-min(aValues))/np.median(aValues) + 4.0*(max(eValues)-min(eValues)) + 4.0*(max(iValues)-min(iValues))
  return tdv

for x in range(1, len(data)):
  for i in range(x+1, len(data)):
    for y in range(i+1, len(data)):
      for z in range(y+1, len(data)):
        tdv = clac(data[x][2],data[i][2],data[y][2],data[z][2],data[x][3],
                   data[i][3],data[y][3],data[z][3],data[x][4],data[i][4],
                   data[y][4],data[z][4])
        tdv_Values.append([data[x][0], data[i][0], data[y][0], data[z][0],tdv])
        
        
        
  tdv_Values.sort(key=lambda l:l[4])
  with open("/content/gdrive/_4Pair/"+str(data[x][0])+".csv","w+") as my_csv:
    csvWriter = csv.writer(my_csv,delimiter=',')
    csvWriter.writerows(tdv_Values)
  tdv_Values = []
  prtin(x)

'''
for x in range(1, len(data)):
	print(x)  
	for i in range(x+1, len(data)):
		for y in range(i+1, len(data)):

			abc = [data[x][2], data[i][2], data[y][2]]
			efg = [data[x][3], data[i][3], data[y][3]]
			hij = [data[x][4], data[i][4], data[y][4]]

			tdv = 2.5*(max(abc)-min(abc))/np.median(abc) + 4.0*(max(efg)-min(efg)) + 4.0*(max(hij)-min(hij))
			tdv_Values.append([data[x][0], data[i][0], data[y][0], tdv]) 


tdv_Values.sort(key=lambda l:l[3])

with open("/content/gdrive/My Drive/tdv_Values.csv","w+") as my_csv:
	csvWriter = csv.writer(my_csv,delimiter=',')
	csvWriter.writerows(tdv_Values)

print(tdv_Values[0:100])
'''
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# [(b'15789', 6.95, 39.4583336, 0.1841545, 0.1019159, 1.456473, -0.916329, -0.390075, 0.08, 100)
#  (b'15807', 7.35, 43.7982074, 0.0729767, 0.0330139, 1.245505,  0.501449, -0.436492, 0.35, 100)
#  (b'15809', 7.64, 42.3286792, 0.2202312, 0.2244278, 1.310848, -0.486295, -0.316855, 0.5 , 100)
#  ...
#  (b'2016BP81', 6.06, 43.7265793, 0.064597 , 0.0616415, 1.248466,  0.52    , -0.431493, 0.83, 100)
#  (b'2016FP59', 5.78, 46.6368753, 0.1604549, 0.090706 , 1.133517,  0.337515, -0.347085, 0.45, 100)
#  (b'2016FW59', 6.08, 43.4338484, 0.0762106, 0.142732 , 1.261196,  0.388558, -0.420972, 0.06, 100)]
# 1185
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
